# %% [markdown]
# <a href="https://colab.research.google.com/github/ssunilkumar/intro_test/blob/master/clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
Adp_file1=pd.read_excel('Node_AAC_Clustering_Adaptive_Sampling_wihtou_outlier_Value_BV_SI_Ver_1.xlsx')
print(Adp_file1.columns)
Adp_file1.head
# Out:
# Index(['Time', 'Untitled', 'Untitled 1', 'Untitled 2'], dtype='object')
# <bound method NDFrame.head of                         Time   Untitled  Untitled 1  Untitled 2
# 0    2020-07-02 09:30:00.039  28.628891        5.00         6.2
# 1    2020-07-02 09:30:05.048  28.635465        5.00         6.2
# 2    2020-07-02 09:30:10.048  28.642022        5.00         6.2
# 3    2020-07-02 09:30:15.048  28.622335        5.00         6.2
# 4    2020-07-02 09:30:20.048  28.628891        5.00         6.2
# ...                      ...        ...         ...         ...
# 4558 2020-07-02 15:53:28.129  55.000000       25.75         6.1
# 4559 2020-07-02 15:53:33.151  55.000000       25.75         6.1
# 4560 2020-07-02 15:53:38.762  55.000000       25.75         6.1
# 4561 2020-07-02 15:53:44.567  55.000000       25.75         6.2
# 4562 2020-07-02 15:53:50.665  55.000000       25.75         6.2
#
# [4563 rows x 4 columns]>

# %%
# %matplotlib inline
plt.figure(figsize=(15,5))
plt.plot(Adp_file1['Untitled 1'][0:4500])
plt.plot(Adp_file1['Untitled'][0:4500])
plt.show
fig.savefig('my_figure.png')

# %%
# %matplotlib inline
plt.figure(figsize=(30,15))
plt.subplot(211)
#plt.figure(figsize=(10,5))
plt.xlabel('Sample Number')
y=plt.ylabel('Temperature',fontsize=15)
plt.plot(Adp_file1['Untitled 1'][0:2000],color='green',linewidth=5.5)

plt.subplot(212)
plt.plot(Adp_file1['Untitled'][0:2000],linewidth=5.5)
#plt.title("Adaptive_Clustring_Approach")
x="Sample Number"
plt.xlabel(x)
y=plt.ylabel('Sampling Interva')
#plt.legend(['SI','Temp'],loc=1)

fig.savefig('my_figure.png')

# %%
# %matplotlib inline
plt.figure(figsize=(10,5))
plt.plot(Adp_file1['Untitled'][0:2000])
plt.title("Adaptive_Clustring_Approach")
x="Sample Number"
plt.xlabel(x)
y=plt.ylabel('Temprature')
plt.legend(['SI','Temp'],loc=1)

fig.savefig('my_figure.png')

# %%
# !pip install -q matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# Selecting previously unselected package libfluidsynth1:amd64.
# (Reading database ... 144379 files and directories currently installed.)
# Preparing to unpack .../libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
