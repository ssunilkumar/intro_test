# %% [markdown]
# <a href="https://colab.research.google.com/github/ssunilkumar/intro_test/blob/master/clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
Adp_file1=pd.read_excel('Node_AAC_Clustering_Adaptive_Sampling_wihtou_outlier_Value_BV_SI_Ver_1.xlsx')
print(Adp_file1.columns)
Adp_file1.head
# Out:
# Index(['Time', 'Untitled', 'Untitled 1', 'Untitled 2'], dtype='object')
# <bound method NDFrame.head of                         Time   Untitled  Untitled 1  Untitled 2
# 0    2020-07-02 09:30:00.039  28.628891        5.00         6.2
# 1    2020-07-02 09:30:05.048  28.635465        5.00         6.2
# 2    2020-07-02 09:30:10.048  28.642022        5.00         6.2
# 3    2020-07-02 09:30:15.048  28.622335        5.00         6.2
# 4    2020-07-02 09:30:20.048  28.628891        5.00         6.2
# ...                      ...        ...         ...         ...
# 4558 2020-07-02 15:53:28.129  55.000000       25.75         6.1
# 4559 2020-07-02 15:53:33.151  55.000000       25.75         6.1
# 4560 2020-07-02 15:53:38.762  55.000000       25.75         6.1
# 4561 2020-07-02 15:53:44.567  55.000000       25.75         6.2
# 4562 2020-07-02 15:53:50.665  55.000000       25.75         6.2
#
# [4563 rows x 4 columns]>

# %%
# %matplotlib inline
fig,ax=plt.subplots(2,1,figsize=(10,15))
#fig.figure(figsize=(25,30))
#plt.figure(figsize=(10,15))
ax[0].plot(Adp_file1['Untitled 1'][0:4000],label='Clustering_SI')
ax[0].set_xlabel('Sample number',fontsize='large',fontweight='bold')
ax[0].set_ylabel('Temperature',fontsize='large',fontweight='bold')
ax[1].plot(Adp_file1['Untitled'][0:4000],label='Clustering_Temp',color='green')
ax[1].set_xlabel('Sample number',fontsize='large',fontweight='bold')
ax[1].set_ylabel('Sampling Interval',fontsize='large',fontweight='bold')
ax[0].legend()
ax[1].legend()
plt.savefig('Clustering_approach_SI_&_Temperature.png')
#ax[2].hist(Adp_file2['Untitled 2'])
#ax[2].bar(Adp_file2['Untitled 2'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
Adp_file2=pd.read_excel('Varinace_based_C5_Node_Adaptive_Sampling_Values_BV_Ver_3.xlsx')
print(Adp_file2.columns)
Adp_file2.head
# Out:
# Index(['Time', 'Untitled', 'Untitled 1', 'Untitled 2'], dtype='object')
# <bound method NDFrame.head of                         Time    Untitled  Untitled 1  Untitled 2
# 0    2020-07-02 09:30:06.257   28.653785         5.6         5.0
# 1    2020-07-02 09:30:11.279   28.640672         5.6         5.0
# 2    2020-07-02 09:30:16.279   28.660359         5.6         5.0
# 3    2020-07-02 09:30:21.279   28.653785         5.6         5.0
# 4    2020-07-02 09:30:26.279   28.647229         5.6         5.0
# ...                      ...         ...         ...         ...
# 4560 2020-07-02 15:53:32.788   55.000000         5.6         5.0
# 4561 2020-07-02 15:53:37.788   55.000000         5.6         5.0
# 4562 2020-07-02 15:53:42.788   55.000000         5.6         5.0
# 4563 2020-07-02 15:53:48.198   55.000000         5.6         5.0
# 4564 2020-07-02 15:53:53.965  590.536759         5.6         5.0
#
# [4565 rows x 4 columns]>

# %%
# %matplotlib inline
#plt.figure(figsize=(25,15))
fig,ax = plt.subplots(2,1,figsize=(10,15))
fig.show()
ax[0].plot(Adp_file2['Untitled'][0:4000])
ax[0].set_xlabel('Sample number')
ax[0].set_ylabel('Temperature')
ax[1].plot(Adp_file2['Untitled 2'][0:4000])
ax[1].set_xlabel('Sample number')
ax[1].set_ylabel('Sampling Interval')
#ax[2].hist(Adp_file2['Untitled 2'], bins = [5,10,15,20,25,30])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig1,ax1=plt.subplots(3,1,figsize=(10,15))
ax1[0].plot(Adp_file1['Untitled 1'][0:4000],label='Clustring',linestyle='dotted',linewidth=3)
ax1[0].plot(Adp_file2['Untitled 2'][0:4000],label='Variance',linestyle='dashed',linewidth=2)
ax1[0].set_xlabel('Sample number')
ax1[0].set_ylabel('Sampling Interval')
ax1[0].legend()
ax1[1].plot(Adp_file1['Untitled'][0:4000],label='Clustring')
ax1[2].plot(Adp_file2['Untitled'][0:4000],label='Variance')
ax1[1].set_xlabel('Sample number')
ax1[1].set_ylabel('Temperature')
ax1[2].set_xlabel('Sample number')
ax1[2].set_ylabel('Temperature')
ax1[1].legend()
ax1[2].legend()

# %%
import numpy as np
x=np.zeros(40,dtype=float)
x1=np.zeros(40,dtype=float)
x2=np.zeros(40,dtype=float)
i=0
k=0
while i<4000:
  #print(i)
  x[k]=Adp_file1['Untitled'][i:i+100].var()
  x1[k]=Adp_file2['Untitled'][i:i+100].var()
  x2[k]=Adp_file3['Untitled'][i:i+100].var()
  #print(x[k])
  i=i+100
  k=k+1
  #print(i)
  #print(k)
fig2,ax2=plt.subplots(2,1,figsize=(10,15))
ax2[0].plot(x,label='Clustring approach_Temp_Varinace',color='red',linewidth=3)
#ax2[0].plot(x1,label='Variance approach_Temp_Variance',color='green',linestyle='dashed',linewidth=4)
ax2[0].plot(x2,label='Variance approach_Temp_Variance',color='blue',linestyle='dotted',linewidth=6)
ax2[0].legend()
ax2[1].legend()
plt.savefig('Variance of 100 values Tempe of Both approach.png')
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
Adp_file3=pd.read_excel('Fixed_Sampling_Values_BV_Ver_1.xlsx')
print(Adp_file3.columns)
Adp_file3.head
# Out:
# Index(['Time', 'Untitled', 'Untitled 1'], dtype='object')
# <bound method NDFrame.head of                         Time Untitled  Untitled 1
# 0    2020-07-02 09:30:03.231  28.6472         5.8
# 1    2020-07-02 09:30:08.233  28.6538         5.8
# 2    2020-07-02 09:30:13.232  28.6407         5.8
# 3    2020-07-02 09:30:18.232  28.6604         5.8
# 4    2020-07-02 09:30:23.232  28.6538         5.8
# ...                      ...      ...         ...
# 4562 2020-07-02 15:53:40.734      #NV         5.8
# 4563 2020-07-02 15:53:46.105      #NV         5.8
# 4564 2020-07-02 15:53:51.932      #NV         5.8
# 4565 2020-07-02 15:54:02.742      #NV         5.8
# 4566 2020-07-02 15:54:10.795  28.2012         5.8
#
# [4567 rows x 3 columns]>

# %%
plt.plot(Adp_file3['Untitled'][0:4000])

# %%
plt.plot(Adp_file3['Untitled 1'])
plt.plot(Adp_file2['Untitled 1'])
plt.plot(Adp_file1['Untitled 2'])
